# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
the list.

# %%
def sumofeven(list):
    sum=0
    for i in list:
        if i%2==0:
            sum+=i
    return sum

# %%
sumofeven([1,2,3,4,5,6,7,8,9])
# Out:
# 20

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reversed(string1):
    result=string1[: :-1]
    return result

# %%
reversed("sairaj")
# Out:
# 'jarias'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
#each number.

# %%
def squares(list1):
    result=[]
    for i in list1:
        result.append(i**2)
    return result

# %%
squares([1,2,3,4,5])
# Out:
# [1, 4, 9, 16, 25]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(num):
    if num < 1 or num > 200:
        print("Number not accepted. Enter a number between 1 and 200.")
        #return False
    
    if num == 1:
        print("number 1 is not a prime number")
        #return False

    for i in range(2, num):
        if num % i == 0:
            return print("number is not prime")  
    
    return print("number is prime number")
# Out:
#   Cell In[32], line 8
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
is_prime(13)
# Out:
# number is prime number

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms

# %%
class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms
        self.current = 0
        self.next = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n_terms:
            raise StopIteration
        # Generate the next Fibonacci number
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            fib = self.current + self.next
            self.current, self.next = self.next, fib
            self.count += 1
            return fib

# Example Usage
n = int(input("Enter the number of terms for the Fibonacci sequence: "))
fib_iter = FibonacciIterator(n)

print("Fibonacci sequence:")
for num in fib_iter:
    print(num, end=" ")
# Out:
# Enter the number of terms for the Fibonacci sequence:  5
# Fibonacci sequence:
# 0 1 1 2 3

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent

# Example Usage
max_exp = int(input("Enter the maximum exponent: "))
print(f"Powers of 2 up to 2^{max_exp}:")
for value in powers_of_two(max_exp):
    print(value, end=" ")
# Out:
# Enter the maximum exponent:  5
# Powers of 2 up to 2^5:
# 1 2 4 8 16 32

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a str

# %%
def read_file_line_by_line(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.strip()  # Strip newline and extra spaces
    except FileNotFoundError:
        print("The file was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example Usage
file_path = input("Enter the file path: ")
print("File contents line by line:")
for line in read_file_line_by_line(file_path):
    print(line)
# Out:
# Enter the file path:  Documents
# File contents line by line:
# The file was not found.

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
# List of tuples
data = [(1, 4), (3, 1), (5, 2), (4, 3)]

# Sorting the list based on the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

print("Sorted list of tuples:", sorted_data)
# Out:
# Sorted list of tuples: [(3, 1), (5, 2), (4, 3), (1, 4)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenhe

# %%
# List of temperatures in Celsius
celsius_temps = [0, 20, 30, 40, 100]

# Convert Celsius to Fahrenheit using map() and a lambda function
fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))

print("Temperatures in Fahrenheit:", fahrenheit_temps)
# Out:
# Temperatures in Fahrenheit: [32.0, 68.0, 86.0, 104.0, 212.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %% [markdown]
# # Function to check if a character is not a vowel
# def is_not_vowel(char):
#     vowels = 'aeiouAEIOU'
#     return char not in vowels
#
# # Input string
# input_string = "Hello, how are you?"
#
# # Use filter() to remove vowels
# result = ''.join(filter(is_not_vowel, input_string))
#
# print("String without vowels:", result)

# %% [markdown]
# #
# ![q11.png](attachment:f41ee773-979e-4acc-8688-cd394013f5a3.png)

# %%
# List of orders with sublists
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Calculate total cost for each order
# Add $10 shipping if the total is less than $100
order_totals = list(map(lambda order: (order[0], round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)), orders))

# Print the results
print("Order Totals:")
for order in order_totals:
    print(f"Order Number: {order[0]}, Total Cost: ${order[1]}")

# %%
#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
#product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#order is smaller than 100,00 €.

# %%
# List of orders with sublists
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Function to calculate the required result
def calculate_order_value(orders):
    result = []
    for order in orders:
        order_number = order[0]
        quantity = order[2]
        price_per_item = order[3]
        total = quantity * price_per_item
        
        # Apply shipping fee if the total is less than 100
        if total < 100:
            total += 10
        
        result.append((order_number, round(total, 2)))
    
    return result

# Call the function and print the results
order_values = calculate_order_value(orders)

print("Order Values with Adjustments:")
for order in order_values:
    print(f"Order Number: {order[0]}, Total: €{order[1]}")
# Out:
# Order Values with Adjustments:
# Order Number: 34587, Total: €163.8
# Order Number: 98762, Total: €284.0
# Order Number: 77226, Total: €108.85
# Order Number: 88112, Total: €84.97
